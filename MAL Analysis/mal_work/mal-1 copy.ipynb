# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time

# %%
# # Make a request to the MyAnimeList top anime page
# url = 'https://myanimelist.net/topanime.php'
# response = requests.get(url)

# # Parse the HTML content of the page with BeautifulSoup
# anime_soup = BeautifulSoup(response.content, 'html.parser')

# # Find the table of top anime and get the rows
# table = anime_soup.find('table', class_='top-ranking-table')
# rows = table.find_all('tr')[1:2] # get the top 50 rows

# %%
# # Initiate Lists
# delay_random = np.random.randint(8,17)
# time.sleep(10)

# title_all = []
# rank_all = []
# popularity_all = []
# show_type_all = []
# episodes_all = []
# status_all = []
# season_all = []
# year_all = []
# producers_all = []
# licensors_all = []
# studio_all = []
# source_all = []
# genres_all = []
# theme_all = []
# demographic_all = []
# score_all = []
# score_count_all = []
# members_all = []
# favorites_all = []

# # Iterate over the rows and extract the data
# for i, row in enumerate(rows):

#     # Delay search to avoid unethical web scraping 
#     delay_random = np.random.randint(8,16)
#     time.sleep(delay_random)

#     rank = i + 1
#     link = row.find('div', class_='di-ib clearfix').a['href']
#     print(link)
#     if i % 10 == 0:
#         print(i)
    
#     anime_response = requests.get(link)
#     soup = BeautifulSoup(anime_response.content, 'html.parser')

#     # Extract the information
#     title = soup.find('div', itemprop='name').strong.text.strip()
#     rank = soup.find('span', class_='numbers ranked').strong.text.strip()[1:]
#     popularity = soup.find('span', class_='numbers popularity').strong.text.strip()[1:]
#     for i in range(10):
#         temp_text = soup.find_all('div', class_='spaceit_pad')[i].span.text.strip()
#         if temp_text == "Type:":
#             shift = i
#             break

#     show_type = episodes = status = season = year = producers = licensors = studio = source = genres = theme = demographic = score = score_count = members = favorites = "N/A"
#     status_unaired = False
#     for i in range(30):
#         cat = soup.find_all('div', class_='spaceit_pad')[shift + i].find('span').text.strip()
#         shift_val = shift + i
#         if cat == "Type:" :
#             if soup.find_all('div', class_='spaceit_pad')[shift_val].a != None:
#                 show_type = soup.find_all('div', class_='spaceit_pad')[shift_val].a.text
#             else:
#                 show_type = soup.find_all('div', class_='spaceit_pad')[shift_val].text.split('\n ')[-1].strip()
#         elif cat == 'Episodes:' : 
#             episodes = soup.find_all('div', class_='spaceit_pad')[shift_val].text.strip().split(' ')[2]
#         elif cat == 'Status:' :
#             status = soup.find_all('div', class_='spaceit_pad')[shift_val].text.split('\n')[-2].strip()
#             if status == "Not yet aired":
#               status_unaired = True
#         elif cat == 'Premiered:':
#             if(status_unaired == False):
#               season = soup.find_all('div', class_='spaceit_pad')[shift_val].a.text.split(' ')[0]
#               year = soup.find_all('div', class_='spaceit_pad')[shift_val].a.text.split(' ')[1]
#         elif cat == 'Producers:' :
#             temp_arr = soup.find_all('div', class_='spaceit_pad')[shift_val].find_all('a')
#             producers = []
#             for ps in temp_arr:
#                 producers.append(ps.text)
#         elif cat == 'Licensors:' :
#             temp_arr = soup.find_all('div', class_='spaceit_pad')[shift_val].find_all('a')
#             licensors = []
#             for ls in temp_arr:
#                 licensors.append(ls.text)
#             licensors
#         elif cat == 'Studios:' :
#             studios_full = soup.find_all('div', class_='spaceit_pad')[shift_val].find_all('a')
#             studio = []
#             for sf in range(len(studios_full)):
#                 studio.append(studios_full[sf].text.strip())
#         elif cat == 'Source:':
#             source = soup.find_all('div', class_='spaceit_pad')[shift_val].text.strip().split('\n')[-1].strip()
#         elif cat == 'Genres:':
#             genres_full = soup.find_all('div', class_='spaceit_pad')[shift_val].find_all('span', itemprop='genre')
#             genres = []
#             for g in range(len(genres_full)):
#                 genres.append(genres_full[g].text.strip())
#         elif cat == 'Theme:':
#             theme = soup.find_all('div', class_='spaceit_pad')[shift_val].find('span', itemprop='genre').text.strip()
#         elif cat == 'Themes:':
#             themes_full = soup.find_all('div', class_='spaceit_pad')[shift_val].find_all('span', itemprop='genre')
#             theme = []
#             for th in range(len(themes_full)):
#                 theme.append(themes_full[th].text.strip())
#         elif cat == "Demographic:":
#             demographic = soup.find_all('div', class_='spaceit_pad')[shift_val].find('span', itemprop='genre').text.strip()
#         elif cat == "Score:":
#             if(status_unaired == False):
#               score = float(soup.find_all('div', class_='spaceit_pad')[shift_val].find('span', itemprop='ratingValue').text.strip())
#               score_count = int(soup.find_all('div', class_='spaceit_pad')[shift_val].find('span', itemprop='ratingCount').text.strip())
#         elif cat == "Members:":
#             members = int(soup.find_all('div', class_='spaceit_pad')[shift_val].text.strip().split(' ')[-1].replace(",",""))
#         elif cat == "Favorites:":
#             favorites = int(soup.find_all('div', class_='spaceit_pad')[shift_val].text.strip().split(' ')[-1].replace(",",""))
#             break

#         else:
#             continue

#     if season == "N/A" and year == "N/A":
#         length = len(soup.find_all('div', class_='spaceit_pad')[shift + 3].text.split('\n ')[1].strip().split(' '))
#         if length <= 2 :
#             year = soup.find_all('div', class_='spaceit_pad')[shift + 3].text.split('\n ')[1].strip().split(' ')[-1]
#         else:
#             year = soup.find_all('div', class_='spaceit_pad')[shift + 3].text.split('\n ')[1].strip().split(' ')[2]

#     # info = [title, rank, popularity, show_type, episodes, status, season, year, producers, licensors, studio, source, genres, theme, demographic, score, score_count, members, favorites]

#     title_all.append(title)
#     rank_all.append(rank)
#     popularity_all.append(popularity)
#     show_type_all.append(show_type)
#     episodes_all.append(episodes)
#     status_all.append(status)
#     season_all.append(season)
#     year_all.append(year)
#     producers_all.append(producers)
#     licensors_all.append(licensors)
#     studio_all.append(studio)
#     source_all.append(source)
#     genres_all.append(genres)
#     theme_all.append(theme)
#     demographic_all.append(demographic)
#     score_all.append(score)
#     score_count_all.append(score_count)
#     members_all.append(members)
#     favorites_all.append(favorites)

# info_dict_050 = {
#     "Title" : title_all,
#     "Rank" : rank_all,
#     "Popularity" : popularity_all,
#     'Score' : score_all,
#     'Score_Count' : score_count_all,
#     "Members" : members_all,
#     'Favorites' : favorites_all,
#     "Type" : show_type_all,
#     'Episodes' : episodes_all,
#     'Status' : status_all,
#     'Season' : season_all,
#     'Year' : year_all,
#     'Producers' : producers_all,
#     'Licensors' : licensors_all,
#     'Studios' : studio_all,
#     'Genres' : genres_all,
#     'Themes' : theme_all,
#     'Demographic' : demographic_all
# }

# %%
# df = pd.DataFrame(info_dict_first_half)
# df.to_csv('mal_451-500_v2.csv') # every iteraion
# Out:
#                               Title Rank Popularity  Score  Score_Count  \
# 0  Fullmetal Alchemist: Brotherhood    1          3   9.11      1968498
# 1         Bleach: Sennen Kessen-hen    2        518   9.10       176150
#
#    Members  Favorites Type Episodes           Status  Season  Year  \
# 0  3096928     213711   TV       64  Finished Airing  Spring  2009
# 1   395099      15982   TV       13  Finished Airing    Fall  2022
#
#                                            Producers  \
# 0  [Aniplex, Square Enix, Mainichi Broadcasting S...
# 1              [TV Tokyo, Aniplex, Dentsu, Shueisha]
#
#                           Licensors    Studios  \
# 0  [Funimation, Aniplex of America]    [Bones]
# 1                       [VIZ Media]  [Pierrot]
#
#                                 Genres    Themes Demographic
# 0  [Action, Adventure, Drama, Fantasy]  Military     Shounen
# 1         [Action, Adventure, Fantasy]       N/A     Shounen

# %%
df0 = pd.read_csv('mal_datasets/mal_pop_1-50.csv')
df1 = pd.read_csv('mal_datasets/mal_pop_51-100.csv')
df2 = pd.read_csv('mal_datasets/mal_pop_101-150.csv')
df3 = pd.read_csv('mal_datasets/mal_pop_151-200.csv')
df4 = pd.read_csv('mal_datasets/mal_pop_201-250.csv')
df5 = pd.read_csv('mal_datasets/mal_pop_251-300.csv')
df6 = pd.read_csv('mal_datasets/mal_pop_301-350.csv')
df7 = pd.read_csv('mal_datasets/mal_pop_351-400.csv')
df8 = pd.read_csv('mal_datasets/mal_pop_401-450.csv')
df9 = pd.read_csv('mal_datasets/mal_pop_451-500.csv') 
df10 = pd.read_csv('mal_datasets/mal_pop_501-550.csv')
df11 = pd.read_csv('mal_datasets/mal_pop_551-600.csv')
df12 = pd.read_csv('mal_datasets/mal_pop_601-650.csv')
df13 = pd.read_csv('mal_datasets/mal_pop_651-700.csv')
df14 = pd.read_csv('mal_datasets/mal_pop_701-750.csv')
df15 = pd.read_csv('mal_datasets/mal_pop_751-800.csv')
df16 = pd.read_csv('mal_datasets/mal_pop_801-850.csv')
df17 = pd.read_csv('mal_datasets/mal_pop_851-900.csv')
df18 = pd.read_csv('mal_datasets/mal_pop_901-950.csv')
df19 = pd.read_csv('mal_datasets/mal_pop_951-1000.csv')


df = pd.concat([df0, df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19]).reset_index(drop=True)
df = df.drop(columns = "Unnamed: 0")
df
# Out:
#                                                  Title  Rank  Popularity  \
# 0                                   Shingeki no Kyojin   111           1
# 1                                           Death Note    80           2
# 2                     Fullmetal Alchemist: Brotherhood     2           3
# 3                                        One Punch Man   129           4
# 4                                     Sword Art Online  3113           5
# ..                                                 ...   ...         ...
# 995      Koukaku Kidoutai: Stand Alone Complex 2nd GIG   121         996
# 996                      Boogiepop wa Warawanai (2019)  3687         997
# 997  Sword Art Online: Progressive Movie - Hoshi Na...   581         998
# 998                    Kujira no Kora wa Sajou ni Utau  3264         999
# 999                         Yuukoku no Moriarty Part 2   289        1000
#
#      Score  Score_Count  Members  Favorites   Type Episodes           Status  \
# 0     8.53    2606155.0  3666477     160638     TV       25  Finished Airing
# 1     8.62    2569010.0  3640099     164958     TV       37  Finished Airing
# 2     9.11    1973141.0  3104299     214087     TV       64  Finished Airing
# 3     8.50    2087800.0  2995422      61395     TV       12  Finished Airing
# 4     7.20    2040692.0  2904838      66325     TV       25  Finished Airing
# ..     ...          ...      ...        ...    ...      ...              ...
# 995   8.52     100739.0   218442       3072     TV       26  Finished Airing
# 996   7.08      65339.0   218396        792     TV       18  Finished Airing
# 997   8.00      71481.0   218318       2070  Movie        1  Finished Airing
# 998   7.17      99705.0   217960        969     TV       12  Finished Airing
# 999   8.26      96082.0   217913       2797     TV       13  Finished Airing
#
#      Season  Year                                          Producers  \
# 0    Spring  2013  ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 1      Fall  2006  ['VAP', 'Konami', 'Ashi Productions', 'Nippon ...
# 2    Spring  2009  ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 3      Fall  2015  ['TV Tokyo', 'Bandai Visual', 'Lantis', 'Asats...
# 4    Summer  2012  ['Aniplex', 'Genco', 'DAX Production', 'ASCII ...
# ..      ...   ...                                                ...
# 995  Winter  2004  ['Bandai Visual', 'Dentsu', 'Victor Entertainm...
# 996  Winter  2019       ['AT-X', 'Kadokawa Media House', 'Kadokawa']
# 997     NaN  2021  ['Aniplex', 'Bandai Namco Entertainment', 'Egg...
# 998    Fall  2017  ['Bandai Visual', 'Lantis', 'Magic Capsule', '...
# 999  Spring  2021  ['Mainichi Broadcasting System', 'Shueisha', '...
#
#                                            Licensors             Studios  \
# 0                                     ['Funimation']      ['Wit Studio']
# 1                                      ['VIZ Media']        ['Madhouse']
# 2               ['Funimation', 'Aniplex of America']           ['Bones']
# 3                                      ['VIZ Media']        ['Madhouse']
# 4                             ['Aniplex of America']    ['A-1 Pictures']
# ..                                               ...                 ...
# 995  ['Bandai Entertainment', 'Manga Entertainment']  ['Production I.G']
# 996                                   ['Funimation']        ['Madhouse']
# 997                           ['Aniplex of America']    ['A-1 Pictures']
# 998                                     ['add some']       ['J.C.Staff']
# 999                                   ['Funimation']  ['Production I.G']
#
#                                                 Genres  \
# 0     ['Action', 'Award Winning', 'Drama', 'Suspense']
# 1                         ['Supernatural', 'Suspense']
# 2          ['Action', 'Adventure', 'Drama', 'Fantasy']
# 3                                 ['Action', 'Comedy']
# 4        ['Action', 'Adventure', 'Fantasy', 'Romance']
# ..                                                 ...
# 995                    ['Action', 'Mystery', 'Sci-Fi']
# 996  ['Avant Garde', 'Drama', 'Horror', 'Mystery', ...
# 997                 ['Action', 'Adventure', 'Fantasy']
# 998                    ['Drama', 'Fantasy', 'Mystery']
# 999                            ['Mystery', 'Suspense']
#
#                                                Themes Demographic
# 0                    ['Gore', 'Military', 'Survival']     Shounen
# 1                                       Psychological     Shounen
# 2                                            Military     Shounen
# 3             ['Adult Cast', 'Parody', 'Super Power']      Seinen
# 4                      ['Love Polygon', 'Video Game']         NaN
# ..                                                ...         ...
# 995  ['Adult Cast', 'Detective', 'Mecha', 'Military']      Seinen
# 996                                     Psychological         NaN
# 997                                        Video Game         NaN
# 998                                       Super Power      Shoujo
# 999     ['Adult Cast', 'Historical', 'Psychological']     Shounen
#
# [1000 rows x 18 columns]

# %%
df['Title'].value_counts()
# Out:
# Shingeki no Kyojin                    1
# Imouto sae Ireba Ii.                  1
# Kanojo mo Kanojo                      1
# Phantom: Requiem for the Phantom      1
# Karigurashi no Arrietty               1
#                                      ..
# Kimetsu no Yaiba: Mugen Ressha-hen    1
# Zetsuen no Tempest                    1
# Shiki                                 1
# Shokugeki no Souma: Shin no Sara      1
# Yuukoku no Moriarty Part 2            1
# Name: Title, Length: 1000, dtype: int64

# %%
# complete_titles = []
# for i in range(20):
#     delay_random = np.random.randint(9, 31)
#     time.sleep(delay_random)
#     val = i * 50
#     url = f'https://myanimelist.net/topanime.php?limit={val}'
    
#     response = requests.get(url)

#     # Parse the HTML content of the page with BeautifulSoup
#     soup = BeautifulSoup(response.content, 'html.parser')

#     # Find the table of top anime and get the rows
#     table = soup.find('table', class_='top-ranking-table')
#     rows = table.find_all('tr')[1:] # skip the header row

#     # Iterate over the rows and extract the data
#     for row in rows:
#         cur_title = row.find('div', class_='di-ib clearfix').a.text.strip()
#         complete_titles.append(cur_title)

# %%
df.to_csv('mal_pop_1000.csv') # Final version
